# %%
name=input("Enter a movie name: ")
r=float(input("Enter the movie's rating (0-5): "))
if r>4.5:
  print(name+" is a Super Hit movie")
elif r>3.5 and r<4.5:
  print(name+" is a Good movie")
elif r>2.5 and r<3.5:
  print(name+" is an Average one time movie")
elif r<2.5 :
  print(name+" is a Flop movie")
# Out:
# Enter a movie name: Mean Girls
# Enter the movie's rating (0-5): 5
# Mean Girls is a Super Hit movie

# %%
pv = int(input("Enter product's purchase value: "))

if pv <= 5000:
    d = 0.05 * pv  # 5% of the purchase value
    dv = pv - d  # Price after discount
    print("Price after discount is:", dv)

elif pv > 5000 and pv <= 10000:
    d = 0.1 * pv  # 10% of the purchase value
    dv = pv - d  # Price after discount
    print("Price after discount is:", dv)

elif pv > 10000 and pv <= 20000:
    d = 0.15 * pv  # 15% of the purchase value
    dv = pv - d  # Price after discount
    print("Price after discount is:", dv)

elif pv > 20000:
    d = 0.25 * pv  # 25% of the purchase value
    dv = pv - d  # Price after discount
    print("Price after discount is:", dv)
# Out:
# Enter product's purchase value: 10000
# Price after discount is: 9000.0
